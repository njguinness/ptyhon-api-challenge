# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
#Set units for search
units = "metric"

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

  # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | stanley
# Processing Record 3 of Set 1 | udachny
# Processing Record 4 of Set 1 | comodoro rivadavia
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | indramayu
# Processing Record 7 of Set 1 | lihue
# Processing Record 8 of Set 1 | kupang
# Processing Record 9 of Set 1 | puerto natales
# Processing Record 10 of Set 1 | touros
# Processing Record 11 of Set 1 | enewetak
# Processing Record 12 of Set 1 | hasaki
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | iqaluit
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | cova figueira
# Processing Record 19 of Set 1 | san-pedro
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | vallo della lucania
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | nar'yan-mar
# Processing Record 25 of Set 1 | papatowai
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | edinburgh of the seven seas
# Processing Record 28 of Set 1 | ust-nera
# Processing Record 29 of Set 1 | waitangi
# Processing Record 30 of Set 1 | bilibino
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | ketchikan
# Processing Record 33 of Set 1 | margaret river
# Processing Record 34 of Set 1 | port augusta
# Processing Record 35 of Set 1 | adamstown
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 38 of Set 1 | kuanda
# Processing Record 39 of Set 1 | fort bragg
# Processing Record 40 of Set 1 | zambezi
# Processing Record 41 of Set 1 | anadyr
# Processing Record 42 of Set 1 | west island
# Processing Record 43 of Set 1 | moree
# Processing Record 44 of Set 1 | padang
# Processing Record 45 of Set 1 | vernon
# Processing Record 46 of Set 1 | colonia
# Processing Record 47 of Set 1 | shurugwi
# Processing Record 48 of Set 1 | arraial do cabo
# Processing Record 49 of Set 1 | tommot
# Processing Record 50 of Set 1 | taltal
# Processing Record 0 of Set 2 | al khums
# Processing Record 1 of Set 2 | bubaque
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | manaquiri
# Processing Record 5 of Set 2 | suihua
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | hotan
# Processing Record 8 of Set 2 | dhidhdhoo
# Processing Record 9 of Set 2 | halden
# Processing Record 10 of Set 2 | isafjordur
# Processing Record 11 of Set 2 | kargopol'
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | tura
# Processing Record 17 of Set 2 | susuman
# Processing Record 18 of Set 2 | zhezqazghan
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | salinopolis
# Processing Record 21 of Set 2 | hami
# Processing Record 22 of Set 2 | pathein
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | acarau
# Processing Record 25 of Set 2 | mogocha
# Processing Record 26 of Set 2 | saipan
# Processing Record 27 of Set 2 | changji
# Processing Record 28 of Set 2 | newman
# Processing Record 29 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 30 of Set 2 | happy valley-goose bay
# Processing Record 31 of Set 2 | saudarkrokur
# Processing Record 32 of Set 2 | picayune
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | egilsstadir
# Processing Record 35 of Set 2 | kingston
# Processing Record 36 of Set 2 | hawaiian paradise park
# Processing Record 37 of Set 2 | diamantino
# Processing Record 38 of Set 2 | teshi old town
# Processing Record 39 of Set 2 | whitehorse
# Processing Record 40 of Set 2 | chonchi
# Processing Record 41 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 42 of Set 2 | kabwe
# Processing Record 43 of Set 2 | donggang
# Processing Record 44 of Set 2 | lambarene
# Processing Record 45 of Set 2 | ivins
# Processing Record 46 of Set 2 | kayangel
# Processing Record 47 of Set 2 | kone
# Processing Record 48 of Set 2 | northam
# Processing Record 49 of Set 2 | crane
# Processing Record 0 of Set 3 | nemuro
# Processing Record 1 of Set 3 | moyynkum
# Processing Record 2 of Set 3 | mount pearl
# Processing Record 3 of Set 3 | bikenibeu village
# Processing Record 4 of Set 3 | crateus
# Processing Record 5 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 3 | st. john's
# Processing Record 7 of Set 3 | navan
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | alesund
# Processing Record 12 of Set 3 | bandarbeyla
# Processing Record 13 of Set 3 | manokwari
# Processing Record 14 of Set 3 | invercargill
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | dubrovnik
# Processing Record 17 of Set 3 | outjo
# Processing Record 18 of Set 3 | new norfolk
# Processing Record 19 of Set 3 | rio grande
# Processing Record 20 of Set 3 | san antonio de pale
# Processing Record 21 of Set 3 | hwange
# Processing Record 22 of Set 3 | aktobe
# Processing Record 23 of Set 3 | rawson
# Processing Record 24 of Set 3 | waingapu
# Processing Record 25 of Set 3 | sanctuary point
# Processing Record 26 of Set 3 | gadzhiyevo
# Processing Record 27 of Set 3 | fortuna
# Processing Record 28 of Set 3 | nishinoomote
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | santarem
# Processing Record 31 of Set 3 | tapa
# Processing Record 32 of Set 3 | badger
# Processing Record 33 of Set 3 | lukolela
# Processing Record 34 of Set 3 | isangel
# Processing Record 35 of Set 3 | san andres
# Processing Record 36 of Set 3 | naliya
# Processing Record 37 of Set 3 | lagoa
# Processing Record 38 of Set 3 | kabalo
# Processing Record 39 of Set 3 | port mathurin
# Processing Record 40 of Set 3 | ribas do rio pardo
# Processing Record 41 of Set 3 | howrah
# Processing Record 42 of Set 3 | hadibu
# Processing Record 43 of Set 3 | keflavik
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | la passe
# Processing Record 46 of Set 3 | fale old settlement
# Processing Record 47 of Set 3 | ancud
# Processing Record 48 of Set 3 | santo antonio do ica
# Processing Record 49 of Set 3 | kununurra
# Processing Record 0 of Set 4 | klyuchi
# Processing Record 1 of Set 4 | vilyuchinsk
# Processing Record 2 of Set 4 | yuzhno-kurilsk
# Processing Record 3 of Set 4 | pervomayskiy
# Processing Record 4 of Set 4 | vallet
# Processing Record 5 of Set 4 | mount isa
# Processing Record 6 of Set 4 | uturoa
# Processing Record 7 of Set 4 | korsakov
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | bamboo flat
# Processing Record 10 of Set 4 | huarmey
# Processing Record 11 of Set 4 | south hedland
# Processing Record 12 of Set 4 | tabas
# Processing Record 13 of Set 4 | kismayo
# Processing Record 14 of Set 4 | dalandzadgad
# Processing Record 15 of Set 4 | olonkinbyen
# Processing Record 16 of Set 4 | arar
# Processing Record 17 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 4 | laichingen
# Processing Record 19 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 20 of Set 4 | brookings
# Processing Record 21 of Set 4 | timbuktu
# Processing Record 22 of Set 4 | hafar al-batin
# Processing Record 23 of Set 4 | morwell
# Processing Record 24 of Set 4 | kerikeri
# Processing Record 25 of Set 4 | keyser
# Processing Record 26 of Set 4 | college
# Processing Record 27 of Set 4 | port lincoln
# Processing Record 28 of Set 4 | pariaman
# Processing Record 29 of Set 4 | bataipora
# Processing Record 30 of Set 4 | olinda
# Processing Record 31 of Set 4 | berdyansk
# Processing Record 32 of Set 4 | papao
# Processing Record 33 of Set 4 | igarka
# Processing Record 34 of Set 4 | kapa'a
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | witu
# Processing Record 37 of Set 4 | aasiaat
# Processing Record 38 of Set 4 | westport
# Processing Record 39 of Set 4 | santa ana
# Processing Record 40 of Set 4 | alvaraes
# Processing Record 41 of Set 4 | denov
# Processing Record 42 of Set 4 | erzincan
# Processing Record 43 of Set 4 | pesqueira
# Processing Record 44 of Set 4 | kitami
# Processing Record 45 of Set 4 | port elizabeth
# Processing Record 46 of Set 4 | khandyga
# Processing Record 47 of Set 4 | menaka
# Processing Record 48 of Set 4 | suomussalmi
# Processing Record 49 of Set 4 | berekum
# Processing Record 0 of Set 5 | kalemie
# Processing Record 1 of Set 5 | ar rutbah
# Processing Record 2 of Set 5 | lenoir city
# Processing Record 3 of Set 5 | chilecito
# Processing Record 4 of Set 5 | seydi
# Processing Record 5 of Set 5 | ulaangom
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | leh
# Processing Record 8 of Set 5 | kham sakae saeng
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | yesilhisar
# Processing Record 11 of Set 5 | boa vista
# Processing Record 12 of Set 5 | delta
# Processing Record 13 of Set 5 | mont-tremblant
# Processing Record 14 of Set 5 | zajecar
# Processing Record 15 of Set 5 | wailua homesteads
# Processing Record 16 of Set 5 | zelenchukskaya
# Processing Record 17 of Set 5 | san juan de miraflores
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | ribeira brava
# Processing Record 20 of Set 5 | san patricio
# Processing Record 21 of Set 5 | yeppoon
# Processing Record 22 of Set 5 | rouyn-noranda
# Processing Record 23 of Set 5 | tralee
# Processing Record 24 of Set 5 | kyren
# Processing Record 25 of Set 5 | laguna
# Processing Record 26 of Set 5 | grand falls-windsor
# Processing Record 27 of Set 5 | pibor
# City not found. Skipping...
# Processing Record 28 of Set 5 | cestos city
# Processing Record 29 of Set 5 | san luis de la loma
# Processing Record 30 of Set 5 | zigong
# Processing Record 31 of Set 5 | al hayy
# Processing Record 32 of Set 5 | kirakira
# Processing Record 33 of Set 5 | valley city
# Processing Record 34 of Set 5 | cockburn town
# Processing Record 35 of Set 5 | senillosa
# Processing Record 36 of Set 5 | kavaratti
# Processing Record 37 of Set 5 | yoakum
# Processing Record 38 of Set 5 | vorgashor
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | port douglas
# Processing Record 41 of Set 5 | pacasmayo
# Processing Record 42 of Set 5 | lorengau
# Processing Record 43 of Set 5 | kolonia
# Processing Record 44 of Set 5 | tshabong
# Processing Record 45 of Set 5 | champerico
# Processing Record 46 of Set 5 | kristiansund
# Processing Record 47 of Set 5 | magadan
# Processing Record 48 of Set 5 | trairi
# Processing Record 49 of Set 5 | porec
# Processing Record 0 of Set 6 | urangan
# Processing Record 1 of Set 6 | archangelos
# Processing Record 2 of Set 6 | carbonear
# Processing Record 3 of Set 6 | morinville
# Processing Record 4 of Set 6 | lensk
# Processing Record 5 of Set 6 | owase
# Processing Record 6 of Set 6 | chibougamau
# Processing Record 7 of Set 6 | ketrzyn
# Processing Record 8 of Set 6 | bairnsdale
# Processing Record 9 of Set 6 | nadi
# Processing Record 10 of Set 6 | sao jose da coroa grande
# Processing Record 11 of Set 6 | bejaia
# Processing Record 12 of Set 6 | nueve de julio
# Processing Record 13 of Set 6 | mariental
# Processing Record 14 of Set 6 | queenstown
# Processing Record 15 of Set 6 | ciudad del carmen
# Processing Record 16 of Set 6 | dudinka
# Processing Record 17 of Set 6 | hutchinson island south
# Processing Record 18 of Set 6 | iskateley
# Processing Record 19 of Set 6 | smolenskaya
# Processing Record 20 of Set 6 | kitakata
# Processing Record 21 of Set 6 | badiyah
# Processing Record 22 of Set 6 | toliara
# Processing Record 23 of Set 6 | shendi
# Processing Record 24 of Set 6 | saynshand
# Processing Record 25 of Set 6 | howard springs
# Processing Record 26 of Set 6 | tabou
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | richards bay
# Processing Record 29 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 30 of Set 6 | utrik
# Processing Record 31 of Set 6 | pitimbu
# Processing Record 32 of Set 6 | tamanrasset
# Processing Record 33 of Set 6 | selibaby
# Processing Record 34 of Set 6 | nacala
# Processing Record 35 of Set 6 | tazovsky
# Processing Record 36 of Set 6 | qaqortoq
# Processing Record 37 of Set 6 | kargasok
# Processing Record 38 of Set 6 | dezhou
# Processing Record 39 of Set 6 | taro
# Processing Record 40 of Set 6 | arkhangel'sk
# Processing Record 41 of Set 6 | moose jaw
# Processing Record 42 of Set 6 | lamu
# Processing Record 43 of Set 6 | farasan
# Processing Record 44 of Set 6 | hastings
# Processing Record 45 of Set 6 | remire-montjoly
# Processing Record 46 of Set 6 | chui
# Processing Record 47 of Set 6 | monitos
# Processing Record 48 of Set 6 | fortaleza
# Processing Record 49 of Set 6 | east london
# Processing Record 0 of Set 7 | bodo
# Processing Record 1 of Set 7 | hirara
# Processing Record 2 of Set 7 | the pas
# Processing Record 3 of Set 7 | hopelchen
# Processing Record 4 of Set 7 | mandleshwar
# Processing Record 5 of Set 7 | tinajo
# Processing Record 6 of Set 7 | kalevala
# Processing Record 7 of Set 7 | itupiranga
# Processing Record 8 of Set 7 | port alfred
# Processing Record 9 of Set 7 | ihosy
# Processing Record 10 of Set 7 | constantia
# Processing Record 11 of Set 7 | zhangjiagang
# Processing Record 12 of Set 7 | tongliao
# Processing Record 13 of Set 7 | vadso
# Processing Record 14 of Set 7 | chernyshevskiy
# Processing Record 15 of Set 7 | lianhe
# Processing Record 16 of Set 7 | elverum
# Processing Record 17 of Set 7 | novyy urgal
# Processing Record 18 of Set 7 | bulayevo
# Processing Record 19 of Set 7 | kasongo-lunda
# Processing Record 20 of Set 7 | qamdo
# Processing Record 21 of Set 7 | karratha
# Processing Record 22 of Set 7 | sierra grande
# Processing Record 23 of Set 7 | zaragoza
# Processing Record 24 of Set 7 | ola
# Processing Record 25 of Set 7 | nusaybin
# Processing Record 26 of Set 7 | afaahiti
# Processing Record 27 of Set 7 | eyl
# Processing Record 28 of Set 7 | weno
# Processing Record 29 of Set 7 | saint-pierre
# Processing Record 30 of Set 7 | mugia
# Processing Record 31 of Set 7 | kuqa
# Processing Record 32 of Set 7 | omutinskiy
# Processing Record 33 of Set 7 | tergnier
# Processing Record 34 of Set 7 | qal'at bishah
# City not found. Skipping...
# Processing Record 35 of Set 7 | hilton head island
# Processing Record 36 of Set 7 | yanta
# Processing Record 37 of Set 7 | bijie
# Processing Record 38 of Set 7 | tokar
# Processing Record 39 of Set 7 | udaipura
# Processing Record 40 of Set 7 | antonio enes
# Processing Record 41 of Set 7 | penzance
# Processing Record 42 of Set 7 | san lawrenz
# Processing Record 43 of Set 7 | dan sadau
# Processing Record 44 of Set 7 | vilyuysk
# Processing Record 45 of Set 7 | hamilton
# Processing Record 46 of Set 7 | ikalamavony
# Processing Record 47 of Set 7 | ocean acres
# Processing Record 48 of Set 7 | swakopmund
# Processing Record 49 of Set 7 | truro
# Processing Record 0 of Set 8 | hepo
# Processing Record 1 of Set 8 | melekeok village
# Processing Record 2 of Set 8 | nagqu
# Processing Record 3 of Set 8 | hays
# Processing Record 4 of Set 8 | tarawa
# Processing Record 5 of Set 8 | salalah
# Processing Record 6 of Set 8 | lautoka
# Processing Record 7 of Set 8 | coquimbo
# Processing Record 8 of Set 8 | ichinohe
# Processing Record 9 of Set 8 | west helena
# Processing Record 10 of Set 8 | bonthe
# Processing Record 11 of Set 8 | ambalangoda
# Processing Record 12 of Set 8 | byron bay
# Processing Record 13 of Set 8 | bennettsville
# Processing Record 14 of Set 8 | bel ombre
# Processing Record 15 of Set 8 | barra de santo antonio
# Processing Record 16 of Set 8 | camden
# Processing Record 17 of Set 8 | lazaro cardenas
# Processing Record 18 of Set 8 | bambanglipuro
# Processing Record 19 of Set 8 | mytilene
# Processing Record 20 of Set 8 | bianzhuang
# Processing Record 21 of Set 8 | huatabampo
# Processing Record 22 of Set 8 | tucurui
# Processing Record 23 of Set 8 | port saint john's
# Processing Record 24 of Set 8 | shamva
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | sarakhs
# Processing Record 27 of Set 8 | dese
# Processing Record 28 of Set 8 | kyzyl-mazhalyk
# Processing Record 29 of Set 8 | obo
# Processing Record 30 of Set 8 | tsiombe
# Processing Record 31 of Set 8 | mbandaka
# Processing Record 32 of Set 8 | yamada
# Processing Record 33 of Set 8 | taoudenni
# Processing Record 34 of Set 8 | dordrecht
# Processing Record 35 of Set 8 | phan thiet
# Processing Record 36 of Set 8 | labrador city
# Processing Record 37 of Set 8 | minas de marcona
# Processing Record 38 of Set 8 | christchurch
# Processing Record 39 of Set 8 | alofi
# Processing Record 40 of Set 8 | camana
# Processing Record 41 of Set 8 | kujang-up
# Processing Record 42 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 43 of Set 8 | chipinge
# Processing Record 44 of Set 8 | verkhnevilyuysk
# Processing Record 45 of Set 8 | namibe
# Processing Record 46 of Set 8 | kavieng
# Processing Record 47 of Set 8 | senec
# Processing Record 48 of Set 8 | malmberget
# Processing Record 49 of Set 8 | trubchevsk
# Processing Record 0 of Set 9 | puerto rico
# Processing Record 1 of Set 9 | sake
# Processing Record 2 of Set 9 | beloyarskiy
# Processing Record 3 of Set 9 | kodok
# City not found. Skipping...
# Processing Record 4 of Set 9 | kalabo
# Processing Record 5 of Set 9 | dabola
# Processing Record 6 of Set 9 | tongchuanshi
# Processing Record 7 of Set 9 | severo-yeniseyskiy
# Processing Record 8 of Set 9 | fort mcmurray
# Processing Record 9 of Set 9 | meulaboh
# Processing Record 10 of Set 9 | guatire
# Processing Record 11 of Set 9 | saint simons island
# City not found. Skipping...
# Processing Record 12 of Set 9 | pishin
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | mariinsk
# Processing Record 15 of Set 9 | sitka
# Processing Record 16 of Set 9 | plastun
# Processing Record 17 of Set 9 | ulsteinvik
# Processing Record 18 of Set 9 | akureyri
# Processing Record 19 of Set 9 | la junta
# Processing Record 20 of Set 9 | kloulklubed
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | castillos
# Processing Record 23 of Set 9 | portland
# Processing Record 24 of Set 9 | tuban
# Processing Record 25 of Set 9 | laayoune plage
# City not found. Skipping...
# Processing Record 26 of Set 9 | bansgaon
# Processing Record 27 of Set 9 | montecristi
# Processing Record 28 of Set 9 | hammerfest
# Processing Record 29 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 9 | mbake
# Processing Record 31 of Set 9 | pisco
# Processing Record 32 of Set 9 | sinabang
# Processing Record 33 of Set 9 | nuriootpa
# Processing Record 34 of Set 9 | pesaro
# Processing Record 35 of Set 9 | bedum
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | patia
# Processing Record 38 of Set 9 | villa gesell
# Processing Record 39 of Set 9 | majuro
# Processing Record 40 of Set 9 | berdigestyakh
# Processing Record 41 of Set 9 | kawalu
# Processing Record 42 of Set 9 | mocimboa
# Processing Record 43 of Set 9 | puerto deseado
# Processing Record 44 of Set 9 | mar del plata
# Processing Record 45 of Set 9 | narasannapeta
# Processing Record 46 of Set 9 | atafu village
# Processing Record 47 of Set 9 | tolanaro
# Processing Record 48 of Set 9 | kukawa
# Processing Record 49 of Set 9 | acajutla
# Processing Record 0 of Set 10 | rongelap
# Processing Record 1 of Set 10 | wynyard
# Processing Record 2 of Set 10 | mournies
# Processing Record 3 of Set 10 | aykhal
# Processing Record 4 of Set 10 | poronaysk
# Processing Record 5 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 10 | kalmunai
# Processing Record 7 of Set 10 | boden
# Processing Record 8 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 9 of Set 10 | caleta de carquin
# Processing Record 10 of Set 10 | naze
# Processing Record 11 of Set 10 | rio verde de mato grosso
# Processing Record 12 of Set 10 | flying fish cove
# Processing Record 13 of Set 10 | goyty
# Processing Record 14 of Set 10 | kish
# Processing Record 15 of Set 10 | larache
# Processing Record 16 of Set 10 | pingyin
# Processing Record 17 of Set 10 | madang
# Processing Record 18 of Set 10 | ust'-ilimsk
# Processing Record 19 of Set 10 | duong dong
# Processing Record 20 of Set 10 | saint-joseph
# Processing Record 21 of Set 10 | tonnerre
# Processing Record 22 of Set 10 | pemba
# Processing Record 23 of Set 10 | sandnessjoen
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | ciudad rodrigo
# Processing Record 26 of Set 10 | yigo village
# Processing Record 27 of Set 10 | miri
# Processing Record 28 of Set 10 | nuuk
# Processing Record 29 of Set 10 | zabol
# Processing Record 30 of Set 10 | bratsk
# Processing Record 31 of Set 10 | brigantine
# Processing Record 32 of Set 10 | bomi
# Processing Record 33 of Set 10 | rabaul
# Processing Record 34 of Set 10 | codo
# Processing Record 35 of Set 10 | marshall
# Processing Record 36 of Set 10 | jurm
# Processing Record 37 of Set 10 | bhiwandi
# Processing Record 38 of Set 10 | nantucket
# Processing Record 39 of Set 10 | el porvenir
# Processing Record 40 of Set 10 | nova sintra
# Processing Record 41 of Set 10 | massenya
# Processing Record 42 of Set 10 | xining
# Processing Record 43 of Set 10 | nguigmi
# Processing Record 44 of Set 10 | karatau
# Processing Record 45 of Set 10 | aral
# Processing Record 46 of Set 10 | horta
# Processing Record 47 of Set 10 | el calafate
# Processing Record 48 of Set 10 | chanika
# Processing Record 49 of Set 10 | maharaganj
# Processing Record 0 of Set 11 | zhangye
# Processing Record 1 of Set 11 | bintulu
# Processing Record 2 of Set 11 | maun
# Processing Record 3 of Set 11 | ivdel'
# Processing Record 4 of Set 11 | monrovia
# Processing Record 5 of Set 11 | hebi
# Processing Record 6 of Set 11 | north battleford
# Processing Record 7 of Set 11 | dickinson
# Processing Record 8 of Set 11 | guerrero negro
# Processing Record 9 of Set 11 | t'ongch'on-up
# Processing Record 10 of Set 11 | djibouti
# Processing Record 11 of Set 11 | salerno
# Processing Record 12 of Set 11 | i-n-salah
# Processing Record 13 of Set 11 | torquay
# Processing Record 14 of Set 11 | antsiranana
# Processing Record 15 of Set 11 | mejit
# Processing Record 16 of Set 11 | mandalgovi
# Processing Record 17 of Set 11 | abu jibeha
# Processing Record 18 of Set 11 | bar-sur-aube
# Processing Record 19 of Set 11 | dumas
# Processing Record 20 of Set 11 | goondiwindi
# Processing Record 21 of Set 11 | porto novo
# Processing Record 22 of Set 11 | souillac
# Processing Record 23 of Set 11 | vuokatti
# Processing Record 24 of Set 11 | odacho-oda
# Processing Record 25 of Set 11 | sabzevar
# Processing Record 26 of Set 11 | honcho
# Processing Record 27 of Set 11 | tangalle
# Processing Record 28 of Set 11 | norman gardens
# Processing Record 29 of Set 11 | masterton
# Processing Record 30 of Set 11 | watsa
# Processing Record 31 of Set 11 | novaya igirma
# Processing Record 32 of Set 11 | bargara
# City not found. Skipping...
# Processing Record 33 of Set 11 | nyurba
# Processing Record 34 of Set 11 | greenville
# Processing Record 35 of Set 11 | novotroitsk
# Processing Record 36 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 37 of Set 11 | aroma
# Processing Record 38 of Set 11 | port shepstone
# Processing Record 39 of Set 11 | ulanhot
# Processing Record 40 of Set 11 | malvan
# Processing Record 41 of Set 11 | kangding
# Processing Record 42 of Set 11 | mangrol
# Processing Record 43 of Set 11 | arak
# Processing Record 44 of Set 11 | baijiantan
# Processing Record 45 of Set 11 | peace river
# Processing Record 46 of Set 11 | gaspe
# Processing Record 47 of Set 11 | coahuayana de hidalgo
# Processing Record 48 of Set 11 | selfoss
# Processing Record 49 of Set 11 | kandyagash
# Processing Record 0 of Set 12 | marabba
# Processing Record 1 of Set 12 | tobi village
# City not found. Skipping...
# Processing Record 2 of Set 12 | plettenberg bay
# Processing Record 3 of Set 12 | negreira
# Processing Record 4 of Set 12 | bucerias
# Processing Record 5 of Set 12 | laikit, laikit ii (dimembe)
# Processing Record 6 of Set 12 | broome
# Processing Record 7 of Set 12 | sosnovoborsk
# Processing Record 8 of Set 12 | chandler
# Processing Record 9 of Set 12 | jemna
# Processing Record 10 of Set 12 | reggane
# Processing Record 11 of Set 12 | castlegar
# Processing Record 12 of Set 12 | al qusayr
# Processing Record 13 of Set 12 | tianshui
# Processing Record 14 of Set 12 | homer
# Processing Record 15 of Set 12 | kidal
# Processing Record 16 of Set 12 | kill devil hills
# Processing Record 17 of Set 12 | gangneung
# Processing Record 18 of Set 12 | la sarre
# Processing Record 19 of Set 12 | chitipa
# Processing Record 20 of Set 12 | barra da estiva
# Processing Record 21 of Set 12 | gitega
# Processing Record 22 of Set 12 | constitucion
# Processing Record 23 of Set 12 | murzuq
# Processing Record 24 of Set 12 | malanje
# Processing Record 25 of Set 12 | darwin
# Processing Record 26 of Set 12 | xinyuan
# Processing Record 27 of Set 12 | tari
# Processing Record 28 of Set 12 | maragogi
# Processing Record 29 of Set 12 | sao caetano de odivelas
# Processing Record 30 of Set 12 | taulaga
# Processing Record 31 of Set 12 | portoferraio
# Processing Record 32 of Set 12 | urucara
# Processing Record 33 of Set 12 | anahuac
# Processing Record 34 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 35 of Set 12 | selsey
# Processing Record 36 of Set 12 | florida
# Processing Record 37 of Set 12 | kapuskasing
# Processing Record 38 of Set 12 | luwingu
# Processing Record 39 of Set 12 | dunedin
# Processing Record 40 of Set 12 | fabens
# Processing Record 41 of Set 12 | bartolome maso
# City not found. Skipping...
# Processing Record 42 of Set 12 | holualoa
# Processing Record 43 of Set 12 | martuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        punta arenas -53.1500  -70.9167      1.06        93         100
# 1             stanley  54.8680   -1.6985      7.93        93          75
# 2             udachny  66.4167  112.4000     20.25        42          93
# 3  comodoro rivadavia -45.8667  -67.5000     11.92        62           0
# 4              bethel  41.3712  -73.4140     19.25        77           0
#
#    Wind Speed Country        Date
# 0        4.63      CL  1718155599
# 1        1.03      GB  1718155599
# 2        2.46      RU  1718155599
# 3        5.14      AR  1718155024
# 4        2.06      US  1718155334

# %%
# Export the City_Data into a csv
city_data_df.to_csv("c:/users/loutz/Module6/Starter_Code/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("c:/users/loutz/Module6/Starter_Code/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0              punta arenas -53.1500  -70.9167      1.06        93
# 1                   stanley  54.8680   -1.6985      7.93        93
# 2                   udachny  66.4167  112.4000     20.25        42
# 3        comodoro rivadavia -45.8667  -67.5000     11.92        62
# 4                    bethel  41.3712  -73.4140     19.25        77
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        4.63      CL  1718155599
# 1                75        1.03      GB  1718155599
# 2                93        2.46      RU  1718155599
# 3                 0        5.14      AR  1718155024
# 4                 0        2.06      US  1718155334

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
from datetime import datetime

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=0.8, edgecolors="k")

# Format the current date
date = datetime.now().strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True)
plt.tight_layout()

# Save the figure
plt.savefig("c:/users/loutz/Module6/Starter_Code/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("c:/users/loutz/Module6/Starter_Code/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("c:/users/loutz/Module6/Starter_Code/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("c:/users/loutz/Module6/Starter_Code/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         stanley  54.8680   -1.6985      7.93        93          75
# 2         udachny  66.4167  112.4000     20.25        42          93
# 4          bethel  41.3712  -73.4140     19.25        77           0
# 6           lihue  21.9789 -159.3672     30.58        70          20
# 10       enewetak  11.3474  162.3373     28.23        79          30
#
#          Wind Speed Country        Date
# City_ID
# 1              1.03      GB  1718155599
# 2              2.46      RU  1718155599
# 4              2.06      US  1718155334
# 6              7.20      US  1718155599
# 10             8.66      MH  1718155599

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0              punta arenas -53.1500  -70.9167      1.06        93
# 3        comodoro rivadavia -45.8667  -67.5000     11.92        62
# 5                 indramayu  -6.3264  108.3200     27.22        79
# 7                    kupang -10.1667  123.5833     32.32        66
# 8            puerto natales -51.7236  -72.4875     -1.88        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        4.63      CL  1718155599
# 3                 0        5.14      AR  1718155024
# 5                 9        1.90      ID  1718155599
# 7                20        5.14      ID  1718155599
# 8                26        1.54      CL  1718155599

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.7127604705320091

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.7417141678217438

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.0030212354466901577

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.1688269355819616

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is 0.032879213416584376

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.07673385934985942

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.11573311299113574

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.24379022505858222

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
